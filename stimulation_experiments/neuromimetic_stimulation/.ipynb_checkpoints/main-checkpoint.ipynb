# %% [markdown]
# # Neuromimetic (ECoG) stimulation

# %%
import numpy as np
from scipy.signal import hilbert

# Function Definitions
import numpy as np

# Function to generate base ECoG-like signals
def generate_ecog_like_base_signals(length, num_signals=8, amplitude_range=(1.0, 8.0)):
    min_amplitude, max_amplitude = amplitude_range
    signals = np.random.uniform(min_amplitude, max_amplitude, (num_signals, length))
    return signals

# Function to scale signals to a specific bit depth
def scale_signals_to_bit_depth(signals, bit_depth):
    max_val = 2**bit_depth - 1
    min_val, current_max_val = np.min(signals), np.max(signals)
    scaled_signals = max_val * (signals - min_val) / (current_max_val - min_val)
    return scaled_signals.astype('uint16') if bit_depth > 8 else scaled_signals.astype('uint8')

def apply_amplitude_variability(signals, variability_factor=0.8):
    random_variability = np.random.normal(1, variability_factor, signals.shape)
    modified_signals = signals * random_variability
    return modified_signals

def apply_variance(signals, variance=1.0):
    noise = np.random.normal(0, np.sqrt(variance), signals.shape)
    modified_signals = signals + noise
    return modified_signals

def apply_signal_with_std(signals, std_dev=1.0):
    noise = np.random.normal(0, std_dev, signals.shape)
    modified_signals = signals + noise
    return modified_signals

def apply_signal_with_rms(signals, rms_value=1.0):
    current_rms = np.sqrt(np.mean(signals**2, axis=1, keepdims=True))
    modified_signals = signals * (rms_value / current_rms)
    return modified_signals

def apply_fractal_structure(signals, fractal_dimension=0.8):
    length = signals.shape[1]
    t = np.arange(length)
    fBm_signal = np.zeros((signals.shape[0], length))
    
    for i in range(1, length):
        delta_t = t[i] - t[i - 1]
        fBm_signal[:, i] = fractal_dimension * fBm_signal[:, i - 1] + np.random.randn(signals.shape[0]) * np.sqrt(delta_t)
    
    modified_signals = signals + fBm_signal
    return modified_signals

def add_peaks(signals, num_peaks=5, peak_height=1.0):
    if len(signals) == 0:
        raise ValueError("Input signals array must not be empty")
    num_signals, signal_length = signals.shape
    for i in range(num_signals):
        for _ in range(num_peaks):
            peak_position = np.random.randint(0, signal_length)
            signals[i, peak_position] += peak_height

    return modified_signals
    
def apply_moving_average(signals, window_size=10):
    modified_signals = np.zeros_like(signals)
    for i, signal in enumerate(signals):
        length = len(signal)
        if length >= window_size:
            cumsum_vec = np.cumsum(np.insert(signal, 0, 0))
            moving_average = (cumsum_vec[window_size:] - cumsum_vec[:-window_size]) / window_size
            modified_signals[i, :length-window_size+1] = moving_average
            modified_signals[i, length-window_size+1:] = signal[-window_size+1:]
        else:
            modified_signals[i] = signal
    return modified_signals

def apply_zero_crossing_rate(signals, target_rate=0.1):
    modified_signals = []
    def calculate_zero_crossing_rate(sig):
        zero_crossings = np.where(np.diff(np.sign(sig)))[0]
        return len(zero_crossings) / len(sig)

    for signal in signals:
        current_rate = calculate_zero_crossing_rate(signal)
        factor = target_rate / current_rate if current_rate > 0 else 1.0
        modified_signal = signal * factor
        modified_signals.append(modified_signal)
    return modified_signals

def apply_arnold_tongues(signals, omega_range=(8, 12), K_range=(1, 8)):
    modified_signals = []
    for signal in signals:
        length = len(signal)
        omega = np.random.uniform(omega_range[0], omega_range[1])
        K = np.random.uniform(K_range[0], K_range[1])
        arnold_tongue_pattern = np.sin(np.linspace(0, 2 * np.pi * omega, length)) * K
        modified_signal = signal + arnold_tongue_pattern
        modified_signals.append(modified_signal)
    return modified_signals

def apply_phase_synchronization(signals, synchronization_level=0.5):
    modified_signals = []
    length = len(signals[0])
    common_phase = np.linspace(0, 2 * np.pi * synchronization_level, length)
    for signal in signals:
        modified_signal = signal + common_phase
        modified_signals.append(modified_signal)
    return modified_signals

def apply_transfer_entropy(signals, influence_factor):
    """
    Modify signals ecog neuromimetically where each signal is influenced by the others.

    Parameters:
    signals (list of numpy.ndarray): List of input signal arrays to modify.
    influence_factor (float): Factor indicating how much signals influence each other (resting state: 1.0).

    Returns:
    list of numpy.ndarray: List of modified signals.
    """
    modified_signals = [np.array(signal) for signal in signals]  # Convert lists to numpy arrays
    num_signals = len(signals)
    
    # Find the maximum length among all signals
    max_length = max(len(signal) for signal in signals)

    # Create a matrix of random interaction weights with the shape (num_signals, num_signals)
    interaction_weights = np.random.uniform(0, influence_factor, (num_signals, num_signals))

    for i in range(1, max_length):
        # Calculate the influence on each signal based on interaction_weights
        influenced_signals = np.dot(interaction_weights, [signal[i - 1] if i <= len(signal) else signal[-1] for signal in signals])

        # Update the current signals based on the calculated influences
        for j in range(num_signals):
            if i <= len(signals[j]):
                modified_signals[j][i] += influenced_signals[j]

    return modified_signals

def apply_hilbert_huang(signals, low_freq_amplitude=1.0, high_freq_amplitude=0.1):
    """
    Modify signals using the Hilbert-Huang transform.
    """
    modified_signals = []  # Initialize the list to store modified signals

    for signal in signals:
        signal = np.array(signal)  # Convert the signal to numpy array
        # Apply low-frequency oscillations
        low_freq_signal = low_freq_amplitude * np.sin(2 * np.pi * 0.1 * np.arange(len(signal)))
        
        # Apply high-frequency noise
        high_freq_noise = high_freq_amplitude * np.random.randn(len(signal))
        
        modulated_signal = signal + low_freq_signal + high_freq_noise
        modified_signals.append(modulated_signal)

    return np.array(modified_signals)  # Return as a NumPy array

def apply_spectral_centroids(signals, centroid_factor=0.8, edge_density_factor=0.8):
    """
    Modify signals to have specific spectral features resembling different states.
    """
    modified_signals = np.zeros_like(signals)  # Initialize an array to store modified signals

    for i in range(signals.shape[0]):
        # Apply FFT to each signal
        fft_spectrum = np.fft.fft(signals[i])
        freq = np.fft.fftfreq(len(signals[i]))
        
        # Calculate spectral centroid and edge density
        centroid = np.sum(freq * np.abs(fft_spectrum)) / np.sum(np.abs(fft_spectrum))
        edge_density = np.sum(np.abs(np.diff(fft_spectrum))) / np.sum(np.abs(fft_spectrum))

        # Adjust spectrum based on centroid and edge density factors
        adjusted_spectrum = fft_spectrum * (centroid_factor * centroid + edge_density_factor * edge_density)
        
        # Transform back to time domain and store in modified_signals
        modified_signals[i] = np.fft.ifft(adjusted_spectrum).real

    return modified_signals

def apply_dynamic_time_warping(signals, reference_signal, warping_factor):
    """
    Apply dynamic time warping to temporally align signals to a reference signal.

    Parameters:
    signals (list of numpy.ndarray): List of input signal arrays to be modified.
    reference_signal (numpy.ndarray): The reference signal to align with.
    warping_factor (float): Factor to control the degree of warping.

    Returns:
    list of numpy.ndarray: List of modified signals with dynamic time warping.
    """
    modified_signals = []

    for signal in signals:
        signal = np.array(signal)  # Convert the signal to numpy array
        modified_signal = np.interp(np.linspace(0, 1, len(signal)), 
                                    np.linspace(0, 1, len(reference_signal)) * warping_factor, 
                                    reference_signal)
        modified_signals.append(modified_signal)

    return modified_signals

def apply_fft(signals, complexity_factor):
    """
    Apply FFT-based spectral complexity to signals.
    """
    modified_signals = []

    for signal in signals:
        # Apply FFT to each signal
        spectrum = np.fft.fft(signal)
        freq = np.fft.fftfreq(len(signal))

        # Apply complexity modification
        modified_spectrum = spectrum * (1 + np.random.randn(len(spectrum)) * complexity_factor)
        
        # Transform back to time domain
        modified_signal = np.fft.ifft(modified_spectrum).real
        modified_signals.append(modified_signal)

    return np.array(modified_signals)

def apply_spectral_centroids(signals, centroid_factor=0.8, edge_density_factor=0.8):
    """
    Modify signals to have specific spectral features resembling different states.
    """
    modified_signals = np.zeros_like(signals)  # Initialize an array to store modified signals

    for i in range(signals.shape[0]):
        # Apply FFT to each signal
        fft_spectrum = np.fft.fft(signals[i])
        freq = np.fft.fftfreq(len(signals[i]))
        
        # Calculate spectral centroid and edge density
        centroid = np.sum(freq * np.abs(fft_spectrum)) / np.sum(np.abs(fft_spectrum))
        edge_density = np.sum(np.abs(np.diff(fft_spectrum))) / np.sum(np.abs(fft_spectrum))

        # Adjust spectrum based on centroid and edge density factors
        adjusted_spectrum = fft_spectrum * (centroid_factor * centroid + edge_density_factor * edge_density)
        
        # Transform back to time domain and store in modified_signals
        modified_signals[i] = np.fft.ifft(adjusted_spectrum).real

    return modified_signals


def apply_signal_evolution(signals, evolution_rate=0.8):
    """
    Modify signals to have an evolving pattern resembling resting state data.

    Parameters:
    signals (numpy.ndarray): Input array of signals to be modified.
    evolution_rate (float): Rate at which the signal evolves (default: 0.8).

    Returns:
    numpy.ndarray: Array of modified signals with an evolving pattern.
    """
    modified_signals = np.zeros_like(signals)
    for i in range(signals.shape[0]):
        modified_signals[i, 0] = np.random.randn()
        for t in range(1, signals.shape[1]):
            modified_signals[i, t] = modified_signals[i, t - 1] + evolution_rate * np.random.randn()
    return modified_signals

def apply_phase_amplitude_coupling(signals, low_freq=8.0, high_freq=40.0):
    """
    Apply phase-amplitude coupling to signals resembling neural data.

    Parameters:
    signals (numpy.ndarray): Input array of signals to be modified.
    low_freq (float): Frequency of the low-frequency oscillation (default: 8.0 Hz).
    high_freq (float): Frequency of the high-frequency oscillation (default: 40.0 Hz).

    Returns:
    numpy.ndarray: Array of modified signals with phase-amplitude coupling.
    """
    modified_signals = np.zeros_like(signals)
    time = np.linspace(0, 1, signals.shape[1])
    for i in range(signals.shape[0]):
        low_freq_signal = np.sin(2 * np.pi * low_freq * time)
        high_freq_signal = np.sin(2 * np.pi * high_freq * time)
        modified_signals[i] = (1 + low_freq_signal) * high_freq_signal
    return modified_signals

def apply_granger_causality(signals, causality_strength=0.8):
    """
    Apply Granger causality relationships to all signals in an ecog neuromimetic manner.

    Parameters:
    signals (numpy.ndarray): Input array of signals to be modified.
    causality_strength (float): Strength of the Granger causal influence (resting state: 0.8).

    Returns:
    numpy.ndarray: Array of modified signals with Granger causal relationships.
    """
    modified_signals = np.copy(signals)
    num_signals, signal_length = signals.shape
    for i in range(1, num_signals):
        for j in range(num_signals):
            if i != j:
                causal_effect = signals[j, :-i] * causality_strength
                modified_signals[i, i:] += causal_effect
    return modified_signals


def apply_multivariate_empirical_mode_decomposition(signals, num_imfs=4):
    """
    Apply Multivariate Empirical Mode Decomposition (MEMD)-like modifications to existing signals.

    Parameters:
    signals (numpy.ndarray): Array of existing signals to be modified.
    num_imfs (int): Number of intrinsic mode functions to simulate (default: 4).

    Returns:
    numpy.ndarray: Array of modified signals simulating MEMD-like signals.
    """
    num_channels, signal_length = signals.shape
    memd_signals = np.zeros((num_channels, num_imfs, signal_length))
    for channel in range(num_channels):
        for imf_idx in range(num_imfs):
            imf = np.sin(2 * np.pi * (imf_idx + 1) * np.linspace(0, 1, signal_length))
            amplitude_scaling = np.random.uniform(0.5, 2.0)
            memd_signals[channel, imf_idx, :] = amplitude_scaling * imf
    modified_signals = signals + np.sum(memd_signals, axis=1)
    return modified_signals

def apply_normalized_states(signals):
    """
    Modify the normalized states based on the input signals.

    Parameters:
    signals (list of numpy.ndarray): List of input signals.

    Returns:
    tuple: Tuple containing modified signals, modified density matrices, and generated coherence values.
    """
    def generate_random_hermitian_matrix(signal_length): 
        """
        Generate a random Hermitian matrix of a specified size.

        Parameters:
        signal_length (int): Length of each signal.

        Returns:
        numpy.ndarray: Random Hermitian matrix.
        """
        size = signal_length
        A = np.random.rand(size, size) + 1j * np.random.rand(size, size)
        return A + A.conj().T

    def construct_density_matrix(signal_length, signals):
        """
        Reconstruct density matrices based on the input signals.

        Parameters:
        signal_length (int): Length of each signal.
        signals (list of numpy.ndarray): List of input signals.

        Returns:
        list: List of reconstructed density matrices.
        """
        reconstructed_density_matrices = []

        for signal in signals:
            hermitian_matrix = generate_random_hermitian_matrix(signal_length)
            eigenvalues, eigenvectors = np.linalg.eigh(hermitian_matrix)
            density_matrix = np.dot(eigenvectors, np.dot(np.diag(eigenvalues), eigenvectors.T.conj()))
            reconstructed_density_matrices.append(density_matrix)

        return reconstructed_density_matrices

    def generate_coherence(density_matrices):
        """
        Generate coherence values for a list of density matrices.

        Parameters:
        density_matrices (list of numpy.ndarray): List of density matrices.

        Returns:
        list: List of generated coherence values.
        """
        coherence_values = []

        for density_matrix in density_matrices:
            eigenvalues = np.linalg.eigvalsh(density_matrix)
            sorted_eigenvalues = np.sort(np.abs(eigenvalues))
            coherence = np.sum(sorted_eigenvalues) - np.sum(sorted_eigenvalues[-2:])
            coherence_values.append(coherence)

        return coherence_values

    signal_length = signals[0].shape[0]
    density_matrices = construct_density_matrix(signal_length, signals)
    coherence_values = generate_coherence(density_matrices)

    modified_signals = []

    for density_matrix in density_matrices:
        reconstructed_signal = np.diag(density_matrix).real
        modified_signals.append(reconstructed_signal)

    return modified_signals, density_matrices, coherence_values

# Import necessary libraries
import numpy as np

# Define the list of transformation functions
transformations = [
    lambda x: scale_signals_to_bit_depth(x, bit_depth),
    lambda x: apply_amplitude_variability(x, variability_factor=0.05),
    lambda x: apply_variance(x, variance=0.5),
    lambda x: apply_signal_with_std(x, std_dev=0.5),
    lambda x: apply_signal_with_rms(x, rms_value=0.5),
    lambda x: apply_fractal_structure(x, fractal_dimension=0.8),  
    lambda x: add_peaks(x, num_peaks=5, peak_height=1.0),
    lambda x: apply_moving_average(x, window_size=10),
    lambda x: apply_zero_crossing_rate(x, target_rate=0.1),
    lambda x: apply_arnold_tongues(x),
    lambda x: apply_phase_synchronization(x, synchronization_level=0.5),
    lambda x: apply_transfer_entropy(x, influence_factor=1.0),
    lambda x: apply_hilbert_huang(x),
    lambda x: apply_dynamic_time_warping(x, reference_signal=np.mean(x, axis=0), warping_factor=0.5),
    lambda x: apply_fft(x, complexity_factor=0.5),
    lambda x: apply_spectral_centroids(x, centroid_factor=0.8, edge_density_factor=0.8),
    lambda x: apply_signal_evolution(x, evolution_rate=0.8),
    lambda x: apply_phase_amplitude_coupling(x, low_freq=8.0, high_freq=40.0),
    lambda x: apply_granger_causality(x, causality_strength=0.8),
    lambda x: apply_multivariate_empirical_mode_decomposition(x, num_imfs=4),
]
# Main function to generate and transform signals
def generate_transformed_signals(signal_length, num_signals, transformation_functions):
    # Generate base signals
    signals = generate_ecog_like_base_signals(signal_length, num_signals)
    print(f"Initial signal range: {signals.min()} to {signals.max()}")

    # Apply transformations
    for transform in transformation_functions:
        signals = transform(signals)
        # Ensure signals is a NumPy array for consistency
        if isinstance(signals, list):
            signals = np.array(signals)
        print(f"After {transform.__name__ if hasattr(transform, '__name__') else 'transformation'} signal range: {signals.min()} to {signals.max()}")

    # Scale to full 16-bit range for processing
    signals = scale_signals_to_bit_depth(signals, 16)
    print(f"Scaled to 16-bit range: {signals.min()} to {signals.max()}")

    return signals

# Main execution
if __name__ == "__main__":
    bit_depth = 16        # Bit depth of the signals
    num_signals = 8      # Number of signals
    sampling_rate = 50   # Sampling rate in Hz
    duration = 5         # Duration in seconds

    # Calculate the length of the signals
    length = sampling_rate * duration

    # Generate and transform the ECoG-like signals
    transformed_signals = generate_transformed_signals(length, num_signals, transformations)

    # Handle 'apply_normalized_states' separately
    modified_signals, density_matrices, coherence_values = apply_normalized_states(transformed_signals)

    # Convert modified_signals to a NumPy array to access the shape attribute
    modified_signals_array = np.array(modified_signals)

    # Check the shape and a sample of the generated signals
    print(f"Shape of generated ECoG-like signals: {modified_signals_array.shape}")
    print(f"Sample of first signal: {modified_signals_array[0][:10]}")
# Out:
# Initial signal range: 1.008850686749533 to 7.99873167065081
# After <lambda> signal range: 0 to 65535
# After <lambda> signal range: 0.0 to 71126.92048665669
# After <lambda> signal range: -0.06566013420915784 to 71126.8657727933
# After <lambda> signal range: 0.950755909971023 to 71126.56072576034
# After <lambda> signal range: 1.263732773960866e-05 to 0.9226987703323926
# After <lambda> signal range: -5.524329584290781 to 6.747171088122593
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 463
#     460 length = sampling_rate * duration
#     462 # Generate and transform the ECoG-like signals
# --> 463 transformed_signals = generate_transformed_signals(length, num_signals, transformations)
#     465 # Handle 'apply_normalized_states' separately
#     466 modified_signals, density_matrices, coherence_values = apply_normalized_states(transformed_signals)
#
# Cell In[1], line 440, in generate_transformed_signals(signal_length, num_signals, transformation_functions)
#     438 # Apply transformations
#     439 for transform in transformation_functions:
# --> 440     signals = transform(signals)
#     441     # Ensure signals is a NumPy array for consistency
#     442     if isinstance(signals, list):
#
# Cell In[1], line 417, in <lambda>(x)
#     407 import numpy as np
#     409 # Define the list of transformation functions
#     410 transformations = [
#     411     lambda x: scale_signals_to_bit_depth(x, bit_depth),
#     412     lambda x: apply_amplitude_variability(x, variability_factor=0.05),
#     413     lambda x: apply_variance(x, variance=0.5),
#     414     lambda x: apply_signal_with_std(x, std_dev=0.5),
#     415     lambda x: apply_signal_with_rms(x, rms_value=0.5),
#     416     lambda x: apply_fractal_structure(x, fractal_dimension=0.8),
# --> 417     lambda x: add_peaks(x, num_peaks=5, peak_height=1.0),
#     418     lambda x: apply_moving_average(x, window_size=10),
#     419     lambda x: apply_zero_crossing_rate(x, target_rate=0.1),
#     420     lambda x: apply_arnold_tongues(x),
#     421     lambda x: apply_phase_synchronization(x, synchronization_level=0.5),
#     422     lambda x: apply_transfer_entropy(x, influence_factor=1.0),
#     423     lambda x: apply_hilbert_huang(x),
#     424     lambda x: apply_dynamic_time_warping(x, reference_signal=np.mean(x, axis=0), warping_factor=0.5),
#     425     lambda x: apply_fft(x, complexity_factor=0.5),
#     426     lambda x: apply_spectral_centroids(x, centroid_factor=0.8, edge_density_factor=0.8),
#     427     lambda x: apply_signal_evolution(x, evolution_rate=0.8),
#     428     lambda x: apply_phase_amplitude_coupling(x, low_freq=8.0, high_freq=40.0),
#     429     lambda x: apply_granger_causality(x, causality_strength=0.8),
#     430     lambda x: apply_multivariate_empirical_mode_decomposition(x, num_imfs=4),
#     431 ]
#     432 # Main function to generate and transform signals
#     433 def generate_transformed_signals(signal_length, num_signals, transformation_functions):
#     434     # Generate base signals
#
# Cell In[1], line 61, in add_peaks(signals, num_peaks, peak_height)
#      58         peak_position = np.random.randint(0, signal_length)
#      59         signals[i, peak_position] += peak_height
# ---> 61 return modified_signals
#
# NameError: name 'modified_signals' is not defined

# %% [markdown]
# # Visualise

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming the signals have been generated and transformed already
# Sample data for the purpose of demonstration
num_signals = 8
signal_length = 50


# Generating random data to simulate the transformed_signals, modified_signals, and signals_for_hardware
# In practice, these would be the actual output from the code provided
transformed_signals = np.random.rand(num_signals, signal_length)
modified_signals = np.random.rand(num_signals, signal_length)
signals_for_hardware = np.random.rand(num_signals, signal_length)

def plot_separate_signals(signals, title_prefix):
    """
    Plot each signal in a separate subplot.

    Parameters:
    signals (numpy.ndarray): Array of signal arrays to plot.
    title_prefix (str): Prefix for the title of each plot.
    """
    plt.figure(figsize=(15, 20))
    plt.style.use('dark_background')

    for i in range(signals.shape[0]):
        plt.subplot(num_signals, 1, i+1)
        plt.plot(signals[i], color='red')
        plt.title(f'{title_prefix} Signal {i+1}', color='red')
        plt.xlabel('Sample', color='red')
        plt.ylabel('Amplitude', color='red')
        plt.xticks(color='red')
        plt.yticks(color='red')
        plt.grid(True, which='both', color='red', linestyle='-', linewidth=0.5)

    plt.tight_layout()
    plt.show()

# Plot the signals in separate subplots
plot_separate_signals(modified_signals, 'Modified')
plot_separate_signals(signals_for_hardware, 'Hardware')
plot_separate_signals(transformed_signals, 'Transformed')
